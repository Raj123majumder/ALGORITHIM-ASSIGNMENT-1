# %% [markdown]
# <a href="https://colab.research.google.com/github/Raj123majumder/ALGORITHIM-ASSIGNMENT-1/blob/main/Algo_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

f = open('/content/normal_data.txt')
array = [float(x) for x in f.read().split(' ')[:-1]]

plt.hist(array, bins = 500)
plt.xlabel('Values in the set')
plt.ylabel('Frequency of occurance')
# Out:
# Text(0, 0.5, 'Frequency of occurance')

# %%
f = open('/content/uniform_data.txt')
array = [float(x) for x in f.read().split(' ')[:-1]]

plt.hist(array, bins = 500)
plt.xlabel('Values in the set')
plt.ylabel('Frequency of occurance')
# Out:
# Text(0, 0.5, 'Frequency of occurance')

# %%
import math

def getCompArray(name):
    f = open(name)
    data = f.read()
    count = [int(x.split(', ')[0]) for x in data.split('\n')[:-1]]
    #avg_time = [float(x.split(', ')[1]) for x in data.split('\n')[:-1]]
    comp = [int(x.split(', ')[2]) for x in data.split('\n')[:-1]]

    comp_ratio = [(c/(n*math.log2(n))) for c, n in zip(comp, count)]
    return comp_ratio


def getTimeArray(name):
    f = open(name)
    data = f.read()
    count = [int(x.split(', ')[0]) for x in data.split('\n')[:-1]]
    avg_time = [float(x.split(', ')[1]) for x in data.split('\n')[:-1]]
    #comp = [int(x.split(', ')[2]) for x in data.split('\n')[:-1]]

    comp_ratio = [(t/(n*math.log2(n))) for t, n in zip(avg_time, count)]
    return comp_ratio


fig, axis = plt.subplots(2, 1, figsize=(10, 7))

fig.suptitle('Comparision and Time Ratio')

axis[0].plot(getCompArray("/content/Merge_sort_nor_infer.txt"), 'o-', label='Normal')
axis[0].plot(getCompArray("/content/Merge_sort_uni_infer.txt"), 'o--', label='Unifrom')
axis[0].legend()
axis[0].set_ylabel(r'$\frac{comp}{n*lgn}$', rotation=0, labelpad=13)

axis[1].plot(getTimeArray("/content/Merge_sort_nor_infer.txt"), 'o--', label='Normal')
axis[1].plot(getTimeArray("/content/Merge_sort_uni_infer.txt"), 'o-', label='Uniform')
axis[1].legend()
axis[1].set_ylabel(r'$\frac{time}{n*lgn}$', rotation=0, labelpad=13)

plt.xlabel(r'n [array size = $2^n$]')
# Out:
# Text(0.5, 0, 'n [array size = $2^n$]')

# %%
def getCompArray(name):
    f = open(name)
    data = f.read()
    count = [int(x.split(', ')[0]) for x in data.split('\n')[:-1]]
    #avg_time = [float(x.split(', ')[1]) for x in data.split('\n')[:-1]]
    comp = [int(x.split(', ')[2]) for x in data.split('\n')[:-1]]

    comp_ratio = [(c/(n*math.log2(n))) for c, n in zip(comp, count)]
    return comp_ratio


def getTimeArray(name):
    f = open(name)
    data = f.read()
    count = [int(x.split(', ')[0]) for x in data.split('\n')[:-1]]
    avg_time = [float(x.split(', ')[1]) for x in data.split('\n')[:-1]]
    #comp = [int(x.split(', ')[2]) for x in data.split('\n')[:-1]]

    comp_ratio = [(t/(n*math.log2(n))) for t, n in zip(avg_time, count)]
    return comp_ratio


fig, axis = plt.subplots(2, 1, figsize=(10, 7))

fig.suptitle('Comparision and Time Ratio')

axis[0].plot(getCompArray("/content/Nor_quick_infer.txt"), 'o-', label='Normal')
axis[0].plot(getCompArray("/content/Uni_quick_infer.txt"), 'o--', label='Unifrom')
axis[0].legend()
axis[0].set_ylabel(r'$\frac{comp}{n*lgn}$', rotation=0, labelpad=13)

axis[1].plot(getTimeArray("/content/Nor_quick_infer.txt"), 'o-', label='Normal')
axis[1].plot(getTimeArray("/content/Uni_quick_infer.txt"), 'o--', label='Uniform')
axis[1].legend()
axis[1].set_ylabel(r'$\frac{time}{n*lgn}$', rotation=0, labelpad=13)

plt.xlabel(r'n [array size = $2^n$]')
# Out:
# Text(0.5, 0, 'n [array size = $2^n$]')

# %%
import matplotlib.pyplot as plt
import math

def getCompArray(name):
    f = open(name)
    data = f.read()
    count = [int(x.split(', ')[0]) for x in data.split('\n')[:-1]]
    #avg_time = [float(x.split(', ')[1]) for x in data.split('\n')[:-1]]
    comp = [int(x.split(', ')[2]) for x in data.split('\n')[:-1]]

    comp_ratio = [(c/(n*math.log2(n))) for c, n in zip(comp, count)]
    return comp_ratio


def getTimeArray(name):
    f = open(name)
    data = f.read()
    count = [int(x.split(', ')[0]) for x in data.split('\n')[:-1]]
    avg_time = [float(x.split(', ')[1]) for x in data.split('\n')[:-1]]
    #comp = [int(x.split(', ')[2]) for x in data.split('\n')[:-1]]

    comp_ratio = [(t/(n*math.log2(n))) for t, n in zip(avg_time, count)]
    return comp_ratio


fig, axis = plt.subplots(2, 1, figsize=(10, 7))

fig.suptitle('Comparision and Time Ratio')

axis[0].plot(getCompArray("/content/rand_quick_nor.txt"), 'o-', label='Normal')
axis[0].plot(getCompArray("/content/rand_quick_uni.txt"), 'o--', label='Unifrom')
axis[0].legend()
axis[0].set_ylabel(r'$\frac{comp}{n*lgn}$', rotation=0, labelpad=13)

axis[1].plot(getTimeArray("/content/rand_quick_nor.txt"), 'o-', label='Normal')
axis[1].plot(getTimeArray("/content/rand_quick_uni.txt"), 'o--', label='Uniform')
axis[1].legend()
axis[1].set_ylabel(r'$\frac{time}{n*lgn}$', rotation=0, labelpad=13)

plt.xlabel(r'n [array size = $2^n$]')
# Out:
# Text(0.5, 0, 'n [array size = $2^n$]')

# %%
import matplotlib.pyplot as plt
import math

def getCompArray(name):
    f = open(name)
    data = f.read()
    count = [int(x.split(', ')[0]) for x in data.split('\n')[:-1]]
    #avg_time = [float(x.split(', ')[1]) for x in data.split('\n')[:-1]]
    comp = [float(x.split(', ')[1]) for x in data.split('\n')[:-1]]

    comp_ratio = [(c/(n*math.log2(n))) for c, n in zip(comp, count)]
    return comp_ratio


def getTimeArray(name):
    f = open(name)
    data = f.read()
    count = [int(x.split(', ')[0]) for x in data.split('\n')[:-1]]
    avg_time = [float(x.split(', ')[1]) for x in data.split('\n')[:-1]]
    #comp = [int(x.split(', ')[2]) for x in data.split('\n')[:-1]]

    comp_ratio = [(t/(n*math.log2(n))) for t, n in zip(avg_time, count)]
    return comp_ratio


fig, axis = plt.subplots(2, 1, figsize=(10, 7))

fig.suptitle('Time Ratio')

axis[0].plot(getCompArray("/content/buck_nor.txt"), 'o-', label='Normal')
axis[0].plot(getCompArray("/content/buck_uni.txt"), 'o--', label='Unifrom')
axis[0].legend()
axis[0].set_ylabel(r'$\frac{time}{n*lgn}$', rotation=0, labelpad=13)

axis[1].plot(getTimeArray("/content/buck_nor.txt"), 'o-', label='Normal')
axis[1].plot(getTimeArray("/content/buck_uni.txt"), 'o--', label='Uniform')
axis[1].legend()
axis[1].set_ylabel(r'$\frac{time}{n*lgn}$', rotation=0, labelpad=13)

plt.xlabel(r'n [array size = $2^n$]')
# Out:
# Text(0.5, 0, 'n [array size = $2^n$]')

# %%
def getSizeArray(name):
    f = open(name)
    data = f.read()
    div_size = [int(x.split(', ')[0]) for x in data.split('\n')[:-1]]
    #avg_time = [float(x.split(', ')[1]) for x in data.split('\n')[:-1]]
    # comp = [int(x.split(', ')[2]) for x in data.split('\n')[:-1]]

    # comp_ratio = [(c/(n*math.log2(n))) for c, n in zip(comp, count)]
    return div_size


def getTimeArray(name):
    f = open(name)
    data = f.read()
    #count = [int(x.split(', ')[0]) for x in data.split('\n')[:-1]]
    avg_time = [float(x.split(', ')[1]) for x in data.split('\n')[:-1]]
    #comp = [int(x.split(', ')[2]) for x in data.split('\n')[:-1]]

    #comp_ratio = [(t/(n*math.log2(n))) for t, n in zip(avg_time, count)]
    return avg_time


plt.plot(getSizeArray("/content/MOM_infer.txt"), getTimeArray("/content/MOM_infer.txt"), '.')
plt.ylabel('Time taken(milliseconds)')
plt.xlabel('subarray size')
plt.title('MoM Observation')
# Out:
# Text(0.5, 1.0, 'MoM Observation')

# %%
from google.colab import files

def getSizeArray(name):
    f = open(name)
    data = f.read()
    div_size = [int(x.split(', ')[0]) for x in data.split('\n')[:-1]]
    #avg_time = [float(x.split(', ')[1]) for x in data.split('\n')[:-1]]
    # comp = [int(x.split(', ')[2]) for x in data.split('\n')[:-1]]

    # comp_ratio = [(c/(n*math.log2(n))) for c, n in zip(comp, count)]
    return div_size

def getpartSize(name):
    f = open(name)
    data = f.read()
    #count = [int(x.split(', ')[0]) for x in data.split('\n')[:-1]]
    #avg_time = [float(x.split(', ')[1]) for x in data.split('\n')[:-1]]
    comp = [int(x.split(', ')[2]) for x in data.split('\n')[:-1]]

    #comp_ratio = [(c/n) for c, n in zip(comp, count)]
    return comp


def getTimeArray(name):
    f = open(name)
    data = f.read()
    #count = [int(x.split(', ')[0]) for x in data.split('\n')[:-1]]
    avg_time = [float(x.split(', ')[1]) for x in data.split('\n')[:-1]]
    #comp = [int(x.split(', ')[2]) for x in data.split('\n')[:-1]]

    #comp_ratio = [(t/n) for t, n in zip(avg_time, count)]
    return avg_time

image = plt.figure(figsize=(6,4), dpi= 100)

plt.plot(getSizeArray("/content/9_nor.txt"), getTimeArray("//content/9_nor.txt"), '.', label = 'Normal')
plt.plot(getSizeArray("/content/9_uni.txt"), getTimeArray("//content/9_uni.txt"), '.', label = 'Uniform')
plt.legend()
plt.ylabel('Time taken')
plt.xlabel('Array size')
plt.title('Partition observation')

image.savefig('myimage.png',  bbox_inches="tight")
files.download('myimage.png')

# %%
def getSizeArray(name):
    f = open(name)
    data = f.read()
    div_size = [int(x.split(', ')[0]) for x in data.split('\n')[:-1]]
    #avg_time = [float(x.split(', ')[1]) for x in data.split('\n')[:-1]]
    # comp = [int(x.split(', ')[2]) for x in data.split('\n')[:-1]]

    # comp_ratio = [(c/(n*math.log2(n))) for c, n in zip(comp, count)]
    return div_size

def getpartSize(name):
    f = open(name)
    data = f.read()
    count = [int(x.split(', ')[0]) for x in data.split('\n')[:-1]]
    #avg_time = [float(x.split(', ')[1]) for x in data.split('\n')[:-1]]
    comp = [int(x.split(', ')[2]) for x in data.split('\n')[:-1]]

    comp_ratio = [(c/n) for c, n in zip(comp, count)]
    return comp_ratio


def getTimeArray(name):
    f = open(name)
    data = f.read()
    #count = [int(x.split(', ')[0]) for x in data.split('\n')[:-1]]
    avg_time = [float(x.split(', ')[1]) for x in data.split('\n')[:-1]]
    #comp = [int(x.split(', ')[2]) for x in data.split('\n')[:-1]]

    #comp_ratio = [(t/n) for t, n in zip(avg_time, count)]
    return avg_time

image = plt.figure(figsize=(6,4), dpi= 100)

plt.plot(getSizeArray("/content/9_nor.txt"), getpartSize("//content/9_nor.txt"), '.', label = 'Normal')
plt.plot(getSizeArray("/content/9_uni.txt"), getpartSize("//content/9_uni.txt"), '.', label = 'Uniform')
plt.legend()
plt.ylabel('pivot element distance')
plt.xlabel('Array size')
plt.title('Partition observation')

image.savefig('myimage.png',  bbox_inches="tight")
files.download('myimage.png')
